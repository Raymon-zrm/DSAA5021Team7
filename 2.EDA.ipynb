# %% [markdown]
# # MovieLens: Spark-based Big Data Recommendation Analysis
#
# # Task2-EDA
# ---

# %% [markdown]
# # 1. Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
ratings = pd.read_csv("/content/drive/MyDrive/ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %% [markdown]
# # 2. EDA on Ratings

# %%
from tqdm import tqdm

average_ratings = []

for i in tqdm(range(1, 7046)):
    average_rating = ratings[ratings['userId'] == i]['rating'].mean()
    average_ratings.append(average_rating)

# 绘制平均值散点图
plt.scatter(range(1, 7046), average_ratings)
plt.xlabel('User ID')
plt.ylabel('Average Rating')
plt.title('Average Rating by User ID')
plt.show()
# Out:
# 100%|██████████| 7045/7045 [05:40<00:00, 20.72it/s]

# %%
from tqdm import tqdm

medians = []

for i in tqdm(range(1, 7046)):
    median_rating = ratings[ratings['userId'] == i]['rating'].median()
    medians.append(median_rating)

# 绘制中位数散点图
plt.scatter(range(1, 7046), medians)
plt.xlabel('User ID')
plt.ylabel('Median Rating')
plt.title('Median Rating by User ID')
plt.show()
# Out:
# 100%|██████████| 7045/7045 [04:42<00:00, 24.90it/s]

# %%
std_devs = []

for i in tqdm(range(1, 7046)):
    std_dev_rating = ratings[ratings['userId'] == i]['rating'].std()
    std_devs.append(std_dev_rating)

# 绘制标准差散点图
plt.scatter(range(1, 7046), std_devs)
plt.xlabel('User ID')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation of Rating by User ID')
plt.show()
# Out:
# 100%|██████████| 7045/7045 [04:28<00:00, 26.26it/s]

# %% [markdown]
# # 3. EDA with Movies

# %%
movies = pd.read_csv("/content/drive/MyDrive/DSC_Project/ml-25m/movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['movieId'].plot(kind='hist', bins=20, title='movieId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
n_ratings = len(ratings)
n_movies = ratings['movieId'].nunique()
n_users = ratings['userId'].nunique()

print(f"Number of ratings: {n_ratings}")
print(f"Number of unique movieId's: {n_movies}")
print(f"Number of unique users: {n_users}")
print(f"Average number of ratings per user: {round(n_ratings/n_users, 2)}")
print(f"Average number of ratings per movie: {round(n_ratings/n_movies, 2)}")
# Out:
# Number of ratings: 25000095
# Number of unique movieId's: 59047
# Number of unique users: 162541
# Average number of ratings per user: 153.81
# Average number of ratings per movie: 423.39

# %%
user_freq = ratings[['userId', 'movieId']].groupby('userId').count().reset_index()
user_freq.columns = ['userId', 'n_ratings']
user_freq.head()
# Out:
#    userId  n_ratings
# 0       1         70
# 1       2        184
# 2       3        656
# 3       4        242
# 4       5        101
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['userId'].plot(kind='hist', bins=20, title='userId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['n_ratings'].plot(kind='hist', bins=20, title='n_ratings')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='userId', y='n_ratings', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# ...

# %%
print(f"Mean number of ratings for a given user: {user_freq['n_ratings'].mean():.2f}.")
# Out:
# Mean number of ratings for a given user: 153.81.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
ax = sns.countplot(x="rating", data=ratings, palette="viridis")
plt.title("Distribution of movie ratings")

plt.subplot(1,2,2)
ax = sns.kdeplot(user_freq['n_ratings'], shade=True, legend=False)
plt.axvline(user_freq['n_ratings'].mean(), color="k", linestyle="--")
plt.xlabel("# ratings per user")
plt.ylabel("density")
plt.title("Number of movies rated per user")
plt.show()

# %%
mean_rating = ratings.groupby('movieId')[['rating']].mean()

lowest_rated = mean_rating['rating'].idxmin()
movies.loc[movies['movieId'] == lowest_rated]
# Out:
#       movieId            title   genres
# 5693     5805  Besotted (2001)  [Drama]

# %%
highest_rated = mean_rating['rating'].idxmax()
movies.loc[movies['movieId'] == highest_rated]
# Out:
#       movieId                                              title  \
# 9416    27914  Hijacking Catastrophe: 9/11, Fear & the Sellin...
#
#              genres
# 9416  [Documentary]

# %%
ratings[ratings['movieId']==highest_rated]
# Out:
#           userId  movieId  rating   timestamp
# 19328266  125475    27914     5.0  1409649085

# %%
movie_stats = ratings.groupby('movieId')[['rating']].agg(['count', 'mean'])
movie_stats.columns = movie_stats.columns.droplevel()

# %%
C = movie_stats['count'].mean()
m = movie_stats['mean'].mean()

def bayesian_avg(ratings):
    bayesian_avg = (C*m+ratings.sum())/(C+ratings.count())
    return bayesian_avg

bayesian_avg_ratings = ratings.groupby('movieId')['rating'].agg(bayesian_avg).reset_index()
bayesian_avg_ratings.columns = ['movieId', 'bayesian_avg']
movie_stats = movie_stats.merge(bayesian_avg_ratings, on='movieId')

# %%
movie_stats = movie_stats.merge(movies[['movieId', 'title']])
movie_stats.sort_values('bayesian_avg', ascending=False).head()
# Out:
#       movieId  count      mean  bayesian_avg                             title
# 314       318  81482  4.413576      4.406638  Shawshank Redemption, The (1994)
# 840       858  52498  4.324336      4.314312             Godfather, The (1972)
# 49         50  55366  4.284353      4.275148        Usual Suspects, The (1995)
# 1190     1221  34188  4.261759      4.247197    Godfather: Part II, The (1974)
# 522       527  60411  4.247579      4.239393           Schindler's List (1993)

# %%
movie_stats.sort_values('bayesian_avg', ascending=True).head()
# Out:
#        movieId  count      mean  bayesian_avg                     title
# 3494      3593   4268  1.578374      1.713116  Battlefield Earth (2000)
# 4669      4775    669  1.125561      1.879725            Glitter (2001)
# 6464      6587    758  1.214380      1.879898              Gigli (2003)
# 11349    50798   1180  1.457203      1.883442         Epic Movie (2007)
# 9603     31698    633  1.232227      1.969341    Son of the Mask (2005)

# %%
from scipy.sparse import csr_matrix

def create_X(df):
    """
    Generates a sparse matrix from ratings dataframe.

    Args:
        df: pandas dataframe

    Returns:
        X: sparse matrix
        user_mapper: dict that maps user id's to user indices
        user_inv_mapper: dict that maps user indices to user id's
        movie_mapper: dict that maps movie id's to movie indices
        movie_inv_mapper: dict that maps movie indices to movie id's
    """
    N = df['userId'].nunique()
    M = df['movieId'].nunique()

    user_mapper = dict(zip(np.unique(df["userId"]), list(range(N))))
    movie_mapper = dict(zip(np.unique(df["movieId"]), list(range(M))))

    user_inv_mapper = dict(zip(list(range(N)), np.unique(df["userId"])))
    movie_inv_mapper = dict(zip(list(range(M)), np.unique(df["movieId"])))

    user_index = [user_mapper[i] for i in df['userId']]
    movie_index = [movie_mapper[i] for i in df['movieId']]

    X = csr_matrix((df["rating"], (movie_index, user_index)), shape=(M, N))

    return X, user_mapper, movie_mapper, user_inv_mapper, movie_inv_mapper

# %%
X, user_mapper, movie_mapper, user_inv_mapper, movie_inv_mapper = create_X(ratings)

# %%
sparsity = X.count_nonzero()/(X.shape[0]*X.shape[1])

print(f"Matrix sparsity: {round(sparsity*100,2)}%")
# Out:
# Matrix sparsity: 0.26%

# %%
from scipy.sparse import save_npz

save_npz('/content/drive/MyDrive/DSC_Project/ml-25m/user_item_matrix.npz', X)

# %%
from sklearn.neighbors import NearestNeighbors

def find_similar_movies(movie_id, X, k, metric='cosine', show_distance=False):
    """
    Finds k-nearest neighbours for a given movie id.

    Args:
        movie_id: id of the movie of interest
        X: user-item utility matrix
        k: number of similar movies to retrieve
        metric: distance metric for kNN calculations

    Returns:
        list of k similar movie ID's
    """
    neighbour_ids = []

    movie_ind = movie_mapper[movie_id]
    movie_vec = X[movie_ind]
    k+=1
    kNN = NearestNeighbors(n_neighbors=k, algorithm="brute", metric=metric)
    kNN.fit(X)
    if isinstance(movie_vec, (np.ndarray)):
        movie_vec = movie_vec.reshape(1,-1)
    neighbour = kNN.kneighbors(movie_vec, return_distance=show_distance)
    for i in range(0,k):
        n = neighbour.item(i)
        neighbour_ids.append(movie_inv_mapper[n])
    neighbour_ids.pop(0)
    return neighbour_ids

# %%
movie_titles = dict(zip(movies['movieId'], movies['title']))

movie_id = 1

similar_ids = find_similar_movies(movie_id, X, k=10)
movie_title = movie_titles[movie_id]

print(f"Because you watched {movie_title}")
for i in similar_ids:
    print(movie_titles[i])
# Out:
# Because you watched Toy Story (1995)
# Star Wars: Episode IV - A New Hope (1977)
# Toy Story 2 (1999)
# Back to the Future (1985)
# Forrest Gump (1994)
# Jurassic Park (1993)
# Star Wars: Episode VI - Return of the Jedi (1983)
# Independence Day (a.k.a. ID4) (1996)
# Lion King, The (1994)
# Aladdin (1992)
# Star Wars: Episode V - The Empire Strikes Back (1980)

# %%
movie_titles = dict(zip(movies['movieId'], movies['title']))

movie_id = 1
similar_ids = find_similar_movies(movie_id, X, k=10, metric="euclidean")

movie_title = movie_titles[movie_id]
print(f"Because you watched {movie_title}:")
for i in similar_ids:
    print(movie_titles[i])

# %%
movies['genres'] = movies['genres'].apply(lambda x: x.split("|"))
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
from collections import Counter

genres_counts = Counter(g for genres in movies['genres'] for g in genres)
print(f"There are {len(genres_counts)} genre labels.")
genres_counts
# Out:
# There are 20 genre labels.
# Counter({'Adventure': 4145,
#          'Animation': 2929,
#          'Children': 2935,
#          'Comedy': 16870,
#          'Fantasy': 2731,
#          'Romance': 7719,
#          'Drama': 25606,
#          'Action': 7348,
#          'Crime': 5319,
#          'Thriller': 8654,
#          'Horror': 5989,
#          'Mystery': 2925,
#          'Sci-Fi': 3595,
#          'IMAX': 195,
#          'Documentary': 5605,
#          'War': 1874,
#          'Musical': 1054,
#          'Western': 1399,
#          'Film-Noir': 353,
#          '(no genres listed)': 5062})

# %%
movies = movies[movies['genres']!='(no genres listed)']

del genres_counts['(no genres listed)']

# %%
print("The 5 most common genres: \n", genres_counts.most_common(5))
# Out:
# The 5 most common genres:
#  [('Drama', 25606), ('Comedy', 16870), ('Thriller', 8654), ('Romance', 7719), ('Action', 7348)]

# %%
genres_counts_df = pd.DataFrame([genres_counts]).T.reset_index()
genres_counts_df.columns = ['genres', 'count']
genres_counts_df = genres_counts_df.sort_values(by='count', ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x='genres', y='count', data=genres_counts_df, palette='viridis')
plt.xticks(rotation=90)
plt.show()
